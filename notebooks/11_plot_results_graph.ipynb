# %% [markdown]
# # 11 — Affichage des graphes de résultat des métriques

# %%
from pathlib import Path
import importlib
import sys

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import src.plot_graph_results
importlib.reload(src.plot_graph_results)
# Out:
# <module 'src.plot_graph_results' from 'd:\\ML\\ML_Project\\src\\plot_graph_results.py'>

# %%
src.plot_graph_results.results_all_models()

# %%
src.plot_graph_results.top_3_plot_graph()
