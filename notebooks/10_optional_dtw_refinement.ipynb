# %% [markdown]
# # 10 — Optionnel : raffinement DTW / similarité temporelle
#
# But : tester une idée optionnelle sans casser le pipeline principal. DTW peut aider si certaines espèces ont des motifs temporels très reconnaissables, mais c'est souvent plus lent.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))
print('PROJECT_ROOT =', PROJECT_ROOT)

# %% [markdown]
# ## Idée expérimentale
#
# Etapes:
# 1. Sélectionner quelques classes confondues dans `outputs/results/errors_*.csv`.
# 2. Extraire les MFCC séquentiels, pas seulement mean/std.
# 3. Mesurer la similarité DTW entre un segment soundscape et des prototypes par classe.
# 4. Ajuster les scores uniquement pour les classes confondues.
#
# améliorer certains cas d'erreur, pas à remplacer les modèles principaux.
