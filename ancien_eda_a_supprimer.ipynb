# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import functions_eda

# %%
train_audio = pd.read_csv("./eda_csv/eda_train_audio_metadata.csv")
soundscapes = pd.read_csv("./eda_csv/eda_soundscapes_metadata.csv")

# %%
train_audio.describe()
# Out:
#        sample_rate      duration
# count      35549.0  35549.000000
# mean       32000.0     34.882595
# std            0.0     74.861287
# min        32000.0      0.008000
# 25%        32000.0     10.788562
# 50%        32000.0     21.000000
# 75%        32000.0     39.837313
# max        32000.0   6881.097000

# %%
train_audio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   species_id   35549 non-null  str
#  1   filepath     35549 non-null  str
#  2   filename     35549 non-null  str
#  3   sample_rate  35549 non-null  int64
#  4   duration     35549 non-null  float64
# dtypes: float64(1), int64(1), str(3)
# memory usage: 1.4 MB

# %%
soundscapes.describe()
# Out:
#        sample_rate  duration
# count      10658.0   10658.0
# mean       32000.0      60.0
# std            0.0       0.0
# min        32000.0      60.0
# 25%        32000.0      60.0
# 50%        32000.0      60.0
# 75%        32000.0      60.0
# max        32000.0      60.0

# %%
soundscapes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10658 entries, 0 to 10657
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   filepath     10658 non-null  str
#  1   filename     10658 non-null  str
#  2   sample_rate  10658 non-null  int64
#  3   duration     10658 non-null  float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 333.2 KB

# %% [markdown]
# Le sample_rate est toujours à 32 kHz pour les deux datasets, on peut donc supprimer cette colonne.
#
# Pour soudscapes, la durée est toujours à 60s, on peut donc également supprimer cette colonne.

# %% [markdown]
# ## Skewness de la durée

# %%
functions_eda.show_skewness(train_audio["duration"], "train_audio", "duration", "Duration (s)", max_value=250)  # max_value à 250 pour éliminer les outliers

# %% [markdown]
# ## Analyse des metadata sur les différentes espèces

# %% [markdown]
# ### Train audio

# %%
species = train_audio["species_id"].unique()
print("Nombre d'espèces :", len(species))
# Out:
# Nombre d'espèces : 206

# %%
value_count_species = train_audio["species_id"].value_counts()

# %%
functions_eda.show_skewness(value_count_species, "train_audio", "nb_row_species", "Nb of rows per species")
