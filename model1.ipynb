# %% [markdown]
# # Entraînement d'un modèle

# %%
import pandas as pd
from fastai import * 
from fastai.vision import *
import os
import librosa
import IPython.display as ipd
import math
import secrets
import glob
import pandas as pd
import numpy as np
import soundfile as sf
from matplotlib import pyplot as plt
pd.set_option('max_rows', None)

# %%
# Chargement des données
train_audio_file = pd.read_csv("eda_csv/train_audio_features.csv")
soundscapes_file = pd.read_csv("eda_csv/soundscapes_features.csv")

# Utile pour le modèle
train_audio_file
